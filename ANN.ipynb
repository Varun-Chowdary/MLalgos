# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import seaborn as sns
from keras.layers import Dense, BatchNormalization, Dropout, LSTM
from keras.models import Sequential
from keras.utils import to_categorical
from keras import callbacks
from sklearn.metrics import precision_score, recall_score, confusion_matrix, classification_report, accuracy_score, f1_score

# %%
#loading data
data = pd.read_csv("sample_data/heart_failure_clinical_records_dataset.csv")
data.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# 2        1     7            1
# 3        0     7            1
# 4        0     8            1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
data['DEATH_EVENT'].count()
# Out:
# 299

# %%
#first of all let us evaluate the target and find out if our data is imbalanced or not
cols= ["#6daa9f","#774571"]
sns.countplot(x= data["smoking"], palette= cols)
# Out:
# <ipython-input-12-56ecc93ee1b9>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x= data["smoking"], palette= cols)
# <Axes: xlabel='smoking', ylabel='count'>

# %%
#Examaning a corelation matrix of all the features
cmap = sns.diverging_palette(275,150,  s=40, l=65, n=9)
corrmat = data.corr()
plt.subplots(figsize=(18,18))
sns.heatmap(corrmat,cmap= cmap,annot=True, square=True);

# %% [markdown]
# Time of the patient's follow-up visit for the disease is crucial in as initial diagnosis with cardiovascular issue and treatment reduces the chances of any fatality. It holds and inverse relation.
# Ejection fraction is the second most important feature. It is quite expected as it is basically the efficiency of the heart.
# Age of the patient is the third most correlated feature. Clearly as heart's functioning declines with ageing.

# %%
#Evaluating the age distribution
plt.figure(figsize=(20,14))
Days_of_week=sns.countplot(x=data['age'], data=data, hue="DEATH_EVENT", palette = cols)
Days_of_week.set_title("Distribution Of Age", color="#774571")
# Out:
# Text(0.5, 1.0, 'Distribution Of Age')

# %%
# Boxen and swarm plot of some non binary features.
feature = ["age","creatinine_phosphokinase","ejection_fraction","platelets","serum_creatinine","serum_sodium", "time"]
for i in feature:
    plt.figure(figsize=(8,8))
    sns.swarmplot(x=data["DEATH_EVENT"], y=data[i], color="black", alpha=0.5)
    sns.boxenplot(x=data["DEATH_EVENT"], y=data[i], palette=cols)
    plt.show()
# Out:
# <ipython-input-16-1b272228e845>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxenplot(x=data["DEATH_EVENT"], y=data[i], palette=cols)
# <ipython-input-16-1b272228e845>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxenplot(x=data["DEATH_EVENT"], y=data[i], palette=cols)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 16.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <ipython-input-16-1b272228e845>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxenplot(x=data["DEATH_EVENT"], y=data[i], palette=cols)
# <ipython-input-16-1b272228e845>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxenplot(x=data["DEATH_EVENT"], y=data[i], palette=cols)
# <ipython-input-16-1b272228e845>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxenplot(x=data["DEATH_EVENT"], y=data[i], palette=cols)
# <ipython-input-16-1b272228e845>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxenplot(x=data["DEATH_EVENT"], y=data[i], palette=cols)
# <ipython-input-16-1b272228e845>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxenplot(x=data["DEATH_EVENT"], y=data[i], palette=cols)

# %%
data.describe().T
# Out:
#                           count           mean           std      min  \
# age                       299.0      60.833893     11.894809     40.0
# anaemia                   299.0       0.431438      0.496107      0.0
# creatinine_phosphokinase  299.0     581.839465    970.287881     23.0
# diabetes                  299.0       0.418060      0.494067      0.0
# ejection_fraction         299.0      38.083612     11.834841     14.0
# high_blood_pressure       299.0       0.351171      0.478136      0.0
# platelets                 299.0  263358.029264  97804.236869  25100.0
# serum_creatinine          299.0       1.393880      1.034510      0.5
# serum_sodium              299.0     136.625418      4.412477    113.0
# sex                       299.0       0.648829      0.478136      0.0
# smoking                   299.0       0.321070      0.467670      0.0
# time                      299.0     130.260870     77.614208      4.0
# DEATH_EVENT               299.0       0.321070      0.467670      0.0
#
#                                25%       50%       75%       max
# age                           51.0      60.0      70.0      95.0
# anaemia                        0.0       0.0       1.0       1.0
# creatinine_phosphokinase     116.5     250.0     582.0    7861.0
# diabetes                       0.0       0.0       1.0       1.0
# ejection_fraction             30.0      38.0      45.0      80.0
# high_blood_pressure            0.0       0.0       1.0       1.0
# platelets                 212500.0  262000.0  303500.0  850000.0
# serum_creatinine               0.9       1.1       1.4       9.4
# serum_sodium                 134.0     137.0     140.0     148.0
# sex                            0.0       1.0       1.0       1.0
# smoking                        0.0       0.0       1.0       1.0
# time                          73.0     115.0     203.0     285.0
# DEATH_EVENT                    0.0       0.0       1.0       1.0

# %%
## Data Preprocessing

X= data.drop(['DEATH_EVENT'],axis=1)
y= data["DEATH_EVENT"]

# %%
#Set up a standard scaler for the features
col_names = list(X.columns)
s_scaler = preprocessing.StandardScaler()
X_df= s_scaler.fit_transform(X)
X_df = pd.DataFrame(X_df, columns=col_names)
X_df.describe().T
# Out:
#                           count          mean       std       min       25%  \
# age                       299.0  5.703353e-16  1.001676 -1.754448 -0.828124
# anaemia                   299.0  1.009969e-16  1.001676 -0.871105 -0.871105
# creatinine_phosphokinase  299.0  0.000000e+00  1.001676 -0.576918 -0.480393
# diabetes                  299.0  9.060014e-17  1.001676 -0.847579 -0.847579
# ejection_fraction         299.0 -3.267546e-17  1.001676 -2.038387 -0.684180
# high_blood_pressure       299.0  0.000000e+00  1.001676 -0.735688 -0.735688
# platelets                 299.0  7.723291e-17  1.001676 -2.440155 -0.520870
# serum_creatinine          299.0  1.425838e-16  1.001676 -0.865509 -0.478205
# serum_sodium              299.0 -8.673849e-16  1.001676 -5.363206 -0.595996
# sex                       299.0 -8.911489e-18  1.001676 -1.359272 -1.359272
# smoking                   299.0 -1.188199e-17  1.001676 -0.687682 -0.687682
# time                      299.0 -1.901118e-16  1.001676 -1.629502 -0.739000
#
#                                50%       75%       max
# age                      -0.070223  0.771889  2.877170
# anaemia                  -0.871105  1.147968  1.147968
# creatinine_phosphokinase -0.342574  0.000166  7.514640
# diabetes                 -0.847579  1.179830  1.179830
# ejection_fraction        -0.007077  0.585389  3.547716
# high_blood_pressure      -0.735688  1.359272  1.359272
# platelets                -0.013908  0.411120  6.008180
# serum_creatinine         -0.284552  0.005926  7.752020
# serum_sodium              0.085034  0.766064  2.582144
# sex                       0.735688  0.735688  0.735688
# smoking                  -0.687682  1.454161  1.454161
# time                     -0.196954  0.938759  1.997038

# %%
#looking at the scaled features
colours =["#774571","#b398af","#f1f1f1" ,"#afcdc7", "#6daa9f"]
plt.figure(figsize=(20,10))
sns.boxenplot(data = X_df,palette = colours)
plt.xticks(rotation=90)
plt.show()
# Out:
# <ipython-input-20-28bc6c119c16>:4: UserWarning:
# The palette list has fewer values (5) than needed (12) and will cycle, which may produce an uninterpretable plot.
#   sns.boxenplot(data = X_df,palette = colours)

# %%
#spliting test and training sets
X_train, X_test, y_train,y_test = train_test_split(X_df,y,test_size=0.25,random_state=42)

# %%
# Early stopping callback
early_stopping = callbacks.EarlyStopping(
    min_delta=0.001,  # minimum amount of change to count as an improvement
    patience=20,  # how many epochs to wait before stopping
    restore_best_weights=True
)

# Initialising the NN with layers
model = Sequential([
    Dense(units=16, kernel_initializer='uniform', activation='relu', input_dim=12),
    Dense(units=8, kernel_initializer='uniform', activation='relu'),
    Dropout(0.25),
    Dense(units=4, kernel_initializer='uniform', activation='relu'),
    Dropout(0.5),
    Dense(units=1, kernel_initializer='uniform', activation='sigmoid')
])

# Compiling the ANN
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the ANN with early stopping
history = model.fit(X_train, y_train, batch_size=32, epochs=500, callbacks=[early_stopping], validation_split=0.2)
# Out:
# Epoch 1/500
# 6/6 [==============================] - 4s 84ms/step - loss: 0.6928 - accuracy: 0.6983 - val_loss: 0.6916 - val_accuracy: 0.7556
# Epoch 2/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.6915 - accuracy: 0.6983 - val_loss: 0.6902 - val_accuracy: 0.7556
# Epoch 3/500
# 6/6 [==============================] - 0s 18ms/step - loss: 0.6904 - accuracy: 0.6983 - val_loss: 0.6886 - val_accuracy: 0.7556
# Epoch 4/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.6892 - accuracy: 0.6983 - val_loss: 0.6870 - val_accuracy: 0.7556
# Epoch 5/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.6878 - accuracy: 0.6983 - val_loss: 0.6853 - val_accuracy: 0.7556
# Epoch 6/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.6863 - accuracy: 0.6983 - val_loss: 0.6834 - val_accuracy: 0.7556
# Epoch 7/500
# 6/6 [==============================] - 0s 51ms/step - loss: 0.6851 - accuracy: 0.6983 - val_loss: 0.6814 - val_accuracy: 0.7556
# Epoch 8/500
# 6/6 [==============================] - 0s 46ms/step - loss: 0.6839 - accuracy: 0.6983 - val_loss: 0.6791 - val_accuracy: 0.7556
# Epoch 9/500
# 6/6 [==============================] - 0s 28ms/step - loss: 0.6814 - accuracy: 0.6983 - val_loss: 0.6765 - val_accuracy: 0.7556
# Epoch 10/500
# 6/6 [==============================] - 0s 26ms/step - loss: 0.6786 - accuracy: 0.6983 - val_loss: 0.6733 - val_accuracy: 0.7556
# Epoch 11/500
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6767 - accuracy: 0.6983 - val_loss: 0.6696 - val_accuracy: 0.7556
# Epoch 12/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.6725 - accuracy: 0.6983 - val_loss: 0.6649 - val_accuracy: 0.7556
# Epoch 13/500
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6679 - accuracy: 0.6983 - val_loss: 0.6590 - val_accuracy: 0.7556
# Epoch 14/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.6627 - accuracy: 0.6983 - val_loss: 0.6520 - val_accuracy: 0.7556
# Epoch 15/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.
500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3999 - accuracy: 0.6983 - val_loss: 0.4078 - val_accuracy: 0.7556
# Epoch 46/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3979 - accuracy: 0.6983 - val_loss: 0.4076 - val_accuracy: 0.7556
# Epoch 47/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4066 - accuracy: 0.6983 - val_loss: 0.4060 - val_accuracy: 0.7556
# Epoch 48/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4194 - accuracy: 0.6983 - val_loss: 0.4047 - val_accuracy: 0.7556
# Epoch 49/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.3994 - accuracy: 0.6983 - val_loss: 0.4036 - val_accuracy: 0.7556
# Epoch 50/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4121 - accuracy: 0.6983 - val_loss: 0.4015 - val_accuracy: 0.7556
# Epoch 51/500
# 6/6 [==============================] - 0s 9ms/step - loss: 0.3937 - accuracy: 0.6983 - val_loss: 0.4016 - val_accuracy: 0.7556
# Epoch 52/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4338 - accuracy: 0.6983 - val_loss: 0.4006 - val_accuracy: 0.7556
# Epoch 53/500
# 6/6 [==============================] - 0s 13ms/step - loss: 0.3934 - accuracy: 0.6983 - val_loss: 0.3991 - val_accuracy: 0.7556
# Epoch 54/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.3872 - accuracy: 0.6983 - val_loss: 0.3987 - val_accuracy: 0.7556
# Epoch 55/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.3944 - accuracy: 0.6983 - val_loss: 0.3986 - val_accuracy: 0.7556
# Epoch 56/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3904 - accuracy: 0.6983 - val_loss: 0.3973 - val_accuracy: 0.7556
# Epoch 57/500
# 6/6 [==============================] - 0s 10ms/step - loss: 0.3820 - accuracy: 0.6983 - val_loss: 0.3948 - val_accuracy: 0.7556
# Epoch 58/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.3723 - accuracy: 0.6983 - val_loss: 0.3952 - val_accuracy: 0.7556
# Epoch 59/500
# 6/6 [==============================] - 0s 15ms/step - loss: 0.3788 - accuracy: 0.6983 - val_loss: 0.3931 - val_accuracy: 0.7556
# Epoch 60/500
# 6/6 [==============================] - 0s 10ms/step - loss: 0.4149 - accuracy: 0.6983 - val_loss: 0.3903 - val_accuracy: 0.7556
# Epoch 61/500
# 6/6 [==============================] - 0s 11ms/step - loss: 0.3810 - accuracy: 0.6983 - val_loss: 0.3889 - val_accuracy: 0.7556
# Epoch 62/500
# 6/6 [==============================] - 0s 18ms/step - loss: 0.3987 - accuracy: 0.6983 - val_loss: 0.3873 - val_accuracy: 0.7556
# Epoch 63/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.3724 - accuracy: 0.6983 - val_loss: 0.3892 - val_accuracy: 0.7556
# Epoch 64/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.4096 - accuracy: 0.6983 - val_loss: 0.3897 - val_accuracy: 0.7556
# Epoch 65/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.3630 - accuracy: 0.6983 - val_loss: 0.3892 - val_accuracy: 0.7556
# Epoch 66/500
# 6/6 [==============================] - 0s 25ms/step - loss: 0.3886 - accuracy: 0.6983 - val_loss: 0.3870 - val_accuracy: 0.7556
# Epoch 67/500
# 6/6 [==============================] - 0s 19ms/step - loss: 0.3618 - accuracy: 0.6983 - val_loss: 0.3831 - val_accuracy: 0.7556
# Epoch 68/500
# 6/6 [==============================] - 0s 19ms/step - loss: 0.3804 - accuracy: 0.6983 - val_loss: 0.3832 - val_accuracy: 0.7556
# Epoch 69/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.3540 - accuracy: 0.6983 - val_loss: 0.3855 - val_accuracy: 0.7556
# Epoch 70/500
# 6/6 [==============================] - 0s 19ms/step - loss: 0.3934 - accuracy: 0.6983 - val_loss: 0.3879 - val_accuracy: 0.7556
# Epoch 71/500
# 6/6 [==============================] - 0s 20ms/step - loss: 0.3716 - accuracy: 0.6983 - val_loss: 0.3898 - val_accuracy: 0.7556
# Epoch 72/500
# 6/6 [==============================] - 0s 18ms/step - loss: 0.3792 - accuracy: 0.6983 - val_loss: 0.3907 - val_accuracy: 0.7556
# Epoch 73/500
# 6/6 [==============================] - 0s 21ms/step - loss: 0.3578 - accuracy: 0.8324 - val_loss: 0.3877 - val_accuracy: 0.7778
# Epoch 74/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.3794 - accuracy: 0.8492 - val_loss: 0.3867 - val_accuracy: 0.7778
# Epoch 75/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3849 - accuracy: 0.8659 - val_loss: 0.3873 - val_accuracy: 0.7778
# Epoch 76/500
# 6/6 [==============================] - 0s 19ms/step - loss: 0.3870 - accuracy: 0.8324 - val_loss: 0.3876 - val_accuracy: 0.7778
# Epoch 77/500
# 6/6 [==============================] - 0s 21ms/step - loss: 0.3796 - accuracy: 0.8547 - val_loss: 0.3848 - val_accuracy: 0.7778
# Epoch 78/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.3735 - accuracy: 0.8380 - val_loss: 0.3837 - val_accuracy: 0.7778
# Epoch 79/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3595 - accuracy: 0.8212 - val_loss: 0.3818 - val_accuracy: 0.7778
# Epoch 80/500
# 6/6 [==============================] - 0s 20ms/step - loss: 0.3702 - accuracy: 0.8212 - val_loss: 0.3834 - val_accuracy: 0.7778
# Epoch 81/500
# 6/6 [==============================] - 0s 18ms/step - loss: 0.3424 - accuracy: 0.8603 - val_loss: 0.3841 - val_accuracy: 0.7778
# Epoch 82/500
# 6/6 [==============================] - 0s 21ms/step - loss: 0.3512 - accuracy: 0.8715 - val_loss: 0.3866 - val_accuracy: 0.7778
# Epoch 83/500
# 6/6 [==============================] - 0s 19ms/step - loss: 0.3682 - accuracy: 0.8771 - val_loss: 0.3867 - val_accuracy: 0.7778
# Epoch 84/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3739 - accuracy: 0.8156 - val_loss: 0.3859 - val_accuracy: 0.7778
# Epoch 85/500
# 6/6 [==============================] - 0s 22ms/step - loss: 0.3601 - accuracy: 0.8603 - val_loss: 0.3872 - val_accuracy: 0.7778
# Epoch 86/500
# 6/6 [==============================] - 0s 18ms/step - loss: 0.3512 - accuracy: 0.8771 - val_loss: 0.3910 - val_accuracy: 0.7778
# Epoch 87/500
# 6/6 [==============================] - 0s 20ms/step - loss: 0.3886 - accuracy: 0.8436 - val_loss: 0.3932 - val_accuracy: 0.7778
# Epoch 88/500
# 6/6 [==============================] - 0s 19ms/step - loss: 0.3787 - accuracy: 0.8492 - val_loss: 0.3928 - val_accuracy: 0.7778
# Epoch 89/500
# 6/6 [==============================] - 0s 18ms/step - loss: 0.3544 - accuracy: 0.8659 - val_loss: 0.3908 - val_accuracy: 0.7778
# Epoch 90/500
# 6/6 [==============================] - 0s 19ms/step - loss: 0.3347 - accuracy: 0.8603 - val_loss: 0.3908 - val_accuracy: 0.7778
# Epoch 91/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3657 - accuracy: 0.8380 - val_loss: 0.3900 - val_accuracy: 0.7778
# Epoch 92/500
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3664 - accuracy: 0.8659 - val_loss: 0.3903 - val_accuracy: 0.7778
# Epoch 93/500
# 6/6 [==============================] - 0s 21ms/step - loss: 0.3543 - accuracy: 0.8939 - val_loss: 0.3893 - val_accuracy: 0.7778
# Epoch 94/500
# 6/6 [==============================] - 0s 19ms/step - loss: 0.3557 - accuracy: 0.8603 - val_loss: 0.3906 - val_accuracy: 0.7556
# Epoch 95/500
# 6/6 [==============================] - 0s 20ms/step - loss: 0.3530 - accuracy: 0.8547 - val_loss: 0.3932 - val_accuracy: 0.7556
# Epoch 96/500
# 6/6 [==============================] - 0s 14ms/step - loss: 0.3525 - accuracy: 0.8492 - val_loss: 0.3935 - val_accuracy: 0.7556
# Epoch 97/500
# 6/6 [==============================] - 0s 18ms/step - loss: 0.3240 - accuracy: 0.9106 - val_loss: 0.3892 - val_accuracy: 0.7556
# Epoch 98/500
# 6/6 [==============================] - 0s 17ms/step - loss: 0.3435 - accuracy: 0.8603 - val_loss: 0.3877 - val_accuracy: 0.7556
# Epoch 99/500
# 6/6 [==============================] - 0s 16ms/step - loss: 0.3450 - accuracy: 0.8659 - val_loss: 0.3921 - val_accuracy: 0.7556

# %%
val_accuracy = np.mean(history.history['val_accuracy'])
print("\n%s: %.2f%%" % ('val_accuracy', val_accuracy*100))
# Out:
# val_accuracy: 76.03%

# %%
## Training and Validation loss over epochs

history_df = pd.DataFrame(history.history)

plt.plot(history_df.loc[:, ['loss']], "#6daa9f", label='Training loss')
plt.plot(history_df.loc[:, ['val_loss']],"#774571", label='Validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="best")

plt.show()

# %%
## Training and validation accuracy over epochs

history_df = pd.DataFrame(history.history)

plt.plot(history_df.loc[:, ['accuracy']], "#6daa9f", label='Training accuracy')
plt.plot(history_df.loc[:, ['val_accuracy']], "#774571", label='Validation accuracy')

plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Predicting the test set results
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5)
np.set_printoptions()
# Out:
# 3/3 [==============================] - 0s 6ms/step

# %%
# confusion matrix
cmap1 = sns.diverging_palette(275,150,  s=40, l=65, n=6)
plt.subplots(figsize=(12,8))
cf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(cf_matrix/np.sum(cf_matrix), cmap = cmap1, annot = True, annot_kws = {'size':15})
# Out:
# <Axes: >

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.91      0.77        44
#            1       0.73      0.35      0.48        31
#
#     accuracy                           0.68        75
#    macro avg       0.70      0.63      0.62        75
# weighted avg       0.69      0.68      0.65        75
